# %% [markdown]
# ## ML ASSIGNMENT - AUTOMOBILE PRICE PREDICTION USING LINEAR REGRESSION

# %% [markdown]
# #### In this Linear regression Machine Learning model, We'll work on automobile dataset which consists of all hardware specifications of differents cars.we are going to predict price of the cars with some indipendent variables from the dataset.

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
sns.set(style = 'darkgrid')
# %matplotlib inline

# %%
car = pd.read_csv('AutoData (1).csv')

# %%
car.head()
# Out:
#    symboling                      make fueltype aspiration doornumber  \
# 0          3        alfa-romero giulia      gas        std        two
# 1          3       alfa-romero stelvio      gas        std        two
# 2          1  alfa-romero Quadrifoglio      gas        std        two
# 3          2               audi 100 ls      gas        std       four
# 4          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  carlength  ...  \
# 0  convertible        rwd          front       88.6      168.8  ...
# 1  convertible        rwd          front       88.6      168.8  ...
# 2    hatchback        rwd          front       94.5      171.2  ...
# 3        sedan        fwd          front       99.8      176.6  ...
# 4        sedan        4wd          front       99.4      176.6  ...
#
#    enginesize  fuelsystem  boreratio stroke compressionratio  horsepower  \
# ...

# %%
car.tail()
# Out:
#      symboling             make fueltype aspiration doornumber carbody  \
# 200         -1  volvo 145e (sw)      gas        std       four   sedan
# 201         -1      volvo 144ea      gas      turbo       four   sedan
# 202         -1      volvo 244dl      gas        std       four   sedan
# 203         -1        volvo 246   diesel      turbo       four   sedan
# 204         -1      volvo 264gl      gas      turbo       four   sedan
#
#     drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 200        rwd          front      109.1      188.8  ...         141
# 201        rwd          front      109.1      188.8  ...         141
# 202        rwd          front      109.1      188.8  ...         173
# 203        rwd          front      109.1      188.8  ...         145
# 204        rwd          front      109.1      188.8  ...         141
#
#      fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  \
# ...

# %% [markdown]
# # Exloratory Data Analysis & Visualization

# %%
car.shape
# Out:
# (205, 25)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   symboling         205 non-null    int64
#  1   make              205 non-null    object
#  2   fueltype          205 non-null    object
#  3   aspiration        205 non-null    object
#  4   doornumber        205 non-null    object
#  5   carbody           205 non-null    object
#  6   drivewheel        205 non-null    object
#  7   enginelocation    205 non-null    object
#  8   wheelbase         205 non-null    float64
#  9   carlength         205 non-null    float64
#  10  carwidth          205 non-null    float64
#  11  carheight         205 non-null    float64
#  12  curbweight        205 non-null    int64
#  13  enginetype        205 non-null    object
#  14  cylindernumber    205 non-null    object
#  15  enginesize        205 non-null    int64
# ...

# %%
car.isnull().sum()
# Out:
# symboling           0
# make                0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %% [markdown]
# ### there are no null values present in the dataset

# %%
car.describe()
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# ...

# %%
car.columns
# Out:
# Index(['symboling', 'make', 'fueltype', 'aspiration', 'doornumber', 'carbody',
#        'drivewheel', 'enginelocation', 'wheelbase', 'carlength', 'carwidth',
#        'carheight', 'curbweight', 'enginetype', 'cylindernumber', 'enginesize',
#        'fuelsystem', 'boreratio', 'stroke', 'compressionratio', 'horsepower',
#        'peakrpm', 'citympg', 'highwaympg', 'price'],
#       dtype='object')

# %%
car.rename(columns = {'make': 'Company_Name'}, inplace = True)

# %%
car.Company_Name.unique()
# Out:
# array(['alfa-romero giulia', 'alfa-romero stelvio',
#        'alfa-romero Quadrifoglio', 'audi 100 ls', 'audi 100ls',
#        'audi fox', 'audi 5000', 'audi 4000', 'audi 5000s (diesel)',
#        'bmw 320i', 'bmw x1', 'bmw x3', 'bmw z4', 'bmw x4', 'bmw x5',
#        'chevrolet impala', 'chevrolet monte carlo', 'chevrolet vega 2300',
#        'dodge rampage', 'dodge challenger se', 'dodge d200',
#        'dodge monaco (sw)', 'dodge colt hardtop', 'dodge colt (sw)',
#        'dodge coronet custom', 'dodge dart custom',
#        'dodge coronet custom (sw)', 'honda civic', 'honda civic cvcc',
#        'honda accord cvcc', 'honda accord lx', 'honda civic 1500 gl',
#        'honda accord', 'honda civic 1300', 'honda prelude',
#        'honda civic (auto)', 'isuzu MU-X', 'isuzu D-Max ',
#        'isuzu D-Max V-Cross', 'jaguar xj', 'jaguar xf', 'jaguar xk',
#        'maxda rx3', 'maxda glc deluxe', 'mazda rx2 coupe', 'mazda rx-4',
# ...

# %%
car.Company_Name = car.Company_Name.str.lower()

# %%
Car_Name = car['Company_Name'].apply(lambda x : x.split(' ')[0])
car.insert(3,"Car_Name",Car_Name)
car.drop(['Company_Name'],axis=1,inplace=True)
car.head()
# Out:
#    symboling fueltype     Car_Name aspiration doornumber      carbody  \
# 0          3      gas  alfa-romero        std        two  convertible
# 1          3      gas  alfa-romero        std        two  convertible
# 2          1      gas  alfa-romero        std        two    hatchback
# 3          2      gas         audi        std       four        sedan
# 4          2      gas         audi        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  ...  enginesize  \
# 0        rwd          front       88.6      168.8  ...         130
# 1        rwd          front       88.6      168.8  ...         130
# 2        rwd          front       94.5      171.2  ...         152
# 3        fwd          front       99.8      176.6  ...         109
# 4        4wd          front       99.4      176.6  ...         136
#
#    fuelsystem  boreratio stroke compressionratio  horsepower peakrpm  citympg  \
# ...

# %%
car.Car_Name.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'maxda', 'mazda', 'buick', 'mercury',
#        'mitsubishi', 'nissan', 'peugeot', 'plymouth', 'porsche',
#        'porcshce', 'renault', 'saab', 'subaru', 'toyota', 'toyouta',
#        'vokswagen', 'volkswagen', 'vw', 'volvo'], dtype=object)

# %%
car.Car_Name = car.Car_Name.str.lower()

# %%
def replace_name(a,b):
    car.Car_Name.replace(a,b,inplace=True)

replace_name('porcshce','porsche')
replace_name('maxda','mazda')
replace_name('vokswagen','volkswagen')
replace_name('vw','volkswagen')
replace_name('toyouta','toyota')

car.Car_Name.unique()
# Out:
# array(['alfa-romero', 'audi', 'bmw', 'chevrolet', 'dodge', 'honda',
#        'isuzu', 'jaguar', 'mazda', 'buick', 'mercury', 'mitsubishi',
#        'nissan', 'peugeot', 'plymouth', 'porsche', 'renault', 'saab',
#        'subaru', 'toyota', 'volkswagen', 'volvo'], dtype=object)

# %%
plt.subplot()
plt.title('Car Price Distribution Plot')
sns.distplot(car.price)
plt.show()

# %%
car.price.describe(percentiles = [0.25,0.50,0.75,0.85,0.90,0.95,1])
# Out:
# count      205.000000
# mean     13276.710571
# std       7988.852332
# min       5118.000000
# 25%       7788.000000
# 50%      10295.000000
# 75%      16503.000000
# 85%      18500.000000
# 90%      22563.000000
# 95%      32472.400000
# 100%     45400.000000
# max      45400.000000
# Name: price, dtype: float64

# %% [markdown]
# #### thus we can say that the data points are far spread out from the mean, which indicates a high variance in the car prices

# %%
plt.figure(figsize=(25, 6))


plt.subplot(1,3,1)
plt1 = car.fueltype.value_counts().plot(kind ='bar', color = 'r')
plt.title('Fuel Type plot')
plt1.set(xlabel = 'Fuel Type', ylabel='Frequency of fuel type')

plt.subplot(1,3,2)
plt1 = car.carbody.value_counts().plot(kind = 'bar', color = 'c')
plt.title('Car Type plot')
plt1.set(xlabel = 'Car Type', ylabel='Frequency of Car type')

plt.show()

# %% [markdown]
# ### 1. there are more number of car which run on gas compared to diesel.Also sedan car type is having maximum sale compared to other car types.

# %%
plt.figure(figsize=(14,8))

plt.title('Engine Type vs Price')
sns.boxplot(x=car.enginetype, y=car.price, palette=("cubehelix"))

plt.show()

# %% [markdown]
# ### looking at the boxplot, ohcv type engine is mostly preferred but the price of ohc type engine is less compared to all.

# %%
plt.figure(figsize=(4,6))

plt.subplot()
plt.title('Door Number vs Price')
sns.countplot(car.doornumber)
plt.show()

# %%
def scatter(x,fig):
    plt.subplot(5,2,fig)
    plt.scatter(car[x],car['price'])
    plt.title(x+' vs Price')
    plt.ylabel('Price')
    plt.xlabel(x)

plt.figure(figsize=(10,20))

scatter('carlength', 1)
scatter('carwidth', 2)
scatter('carheight', 3)
scatter('curbweight', 4)

plt.tight_layout()
plt.show()

# %%
car['fueleconomy'] = (0.55 * car['citympg']) + (0.45 * car['highwaympg'])

# %%
car.head()
# Out:
#    symboling fueltype     Car_Name aspiration doornumber      carbody  \
# 0          3      gas  alfa-romero        std        two  convertible
# 1          3      gas  alfa-romero        std        two  convertible
# 2          1      gas  alfa-romero        std        two    hatchback
# 3          2      gas         audi        std       four        sedan
# 4          2      gas         audi        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  ...  fuelsystem  boreratio  \
# 0        rwd          front       88.6      168.8  ...        mpfi       3.47
# 1        rwd          front       88.6      168.8  ...        mpfi       3.47
# 2        rwd          front       94.5      171.2  ...        mpfi       2.68
# 3        fwd          front       99.8      176.6  ...        mpfi       3.19
# 4        4wd          front       99.4      176.6  ...        mpfi       3.19
#
# ...

# %%
plt.figure(figsize=(8,6))

plt.title('Fuel economy vs Price')
sns.scatterplot(x=car['fueleconomy'],y=car['price'],hue=car['drivewheel'])
plt.xlabel('Fuel Economy')
plt.ylabel('Price')

plt.show()

# %%
car['fuel'] = car.fueltype.apply(lambda x:1 if x == 'gas' else 0)
car['no.of doors'] = car.doornumber.apply(lambda x:1 if x == 'two' else 0)
car['Aspiration'] = car.aspiration.apply(lambda x:1 if x == 'std' else 0)
car.head()
# Out:
#    symboling fueltype     Car_Name aspiration doornumber      carbody  \
# 0          3      gas  alfa-romero        std        two  convertible
# 1          3      gas  alfa-romero        std        two  convertible
# 2          1      gas  alfa-romero        std        two    hatchback
# 3          2      gas         audi        std       four        sedan
# 4          2      gas         audi        std       four        sedan
#
#   drivewheel enginelocation  wheelbase  carlength  ...  compressionratio  \
# 0        rwd          front       88.6      168.8  ...               9.0
# 1        rwd          front       88.6      168.8  ...               9.0
# 2        rwd          front       94.5      171.2  ...               9.0
# 3        fwd          front       99.8      176.6  ...              10.0
# 4        4wd          front       99.4      176.6  ...               8.0
#
#    horsepower  peakrpm citympg highwaympg    price fueleconomy  fuel  \
# ...

# %%
car.corr()
# Out:
#                   symboling  wheelbase  carlength  carwidth  carheight  \
# symboling          1.000000  -0.531954  -0.357612 -0.232919  -0.541038
# wheelbase         -0.531954   1.000000   0.874587  0.795144   0.589435
# carlength         -0.357612   0.874587   1.000000  0.841118   0.491029
# carwidth          -0.232919   0.795144   0.841118  1.000000   0.279210
# carheight         -0.541038   0.589435   0.491029  0.279210   1.000000
# curbweight        -0.227691   0.776386   0.877728  0.867032   0.295572
# enginesize        -0.105790   0.569329   0.683360  0.735433   0.067149
# boreratio         -0.130051   0.488750   0.606454  0.559150   0.171071
# stroke            -0.008735   0.160959   0.129533  0.182942  -0.055307
# compressionratio  -0.178515   0.249786   0.158414  0.181129   0.261214
# horsepower         0.070873   0.353294   0.552623  0.640732  -0.108802
# peakrpm            0.273606  -0.360469  -0.287242 -0.220012  -0.320411
# ...

# %%
sns.heatmap(car.corr())
plt.show()

# %%
car.horsepower.plot(kind="box")

# %%
car[car.horsepower==car.horsepower.max()]
# Out:
#      symboling fueltype Car_Name aspiration doornumber    carbody drivewheel  \
# 129          1      gas  porsche        std        two  hatchback        rwd
#
#     enginelocation  wheelbase  carlength  ...  compressionratio  horsepower  \
# 129          front       98.4      175.7  ...              10.0         288
#
#      peakrpm citympg highwaympg    price fueleconomy  fuel  no.of doors  \
# 129     5750      17         28  31400.5       21.95     1            1
#
#      Aspiration
# 129           1
#
# [1 rows x 29 columns]

# %%
car1 = car.drop(index=129)

# %% [markdown]
# #### droping the row which is having max. outlier value

# %% [markdown]
# # Training & Testing Split

# %%
X = car1.loc[:,['horsepower','enginesize', 'carlength', 'carwidth']]
y = car1.price

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.20,random_state=15)

# %%
print("X_train shape", X_train.shape)
print("X_test shape", X_test.shape)
print("y_train shape", y_train.shape)
print("y_test shape", y_test.shape)
# Out:
# X_train shape (163, 4)
# X_test shape (41, 4)
# y_train shape (163,)
# y_test shape (41,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_predict = model.predict(X_test)

# %% [markdown]
# # MODEL EVALUTION

# %%
from sklearn.metrics import r2_score, accuracy_score
from sklearn import metrics

# %%
r2_score(y_test,y_predict)
# Out:
# 0.8572111644634757

# %%
y_test
# Out:
# 169     9989.000
# 179    15998.000
# 12     20970.000
# 195    13415.000
# 72     35056.000
# 40     10295.000
# 30      6479.000
# 98      8249.000
# 58     15645.000
# 116    17950.000
# 182     7775.000
# 143     9960.000
# 154     7898.000
# 150     5348.000
# 71     34184.000
# 26      7609.000
# 9      17859.167
# 173     8948.000
# 113    16695.000
# 137    18620.000
# 148     8013.000
# 36      7295.000
# 94      7299.000
# 47     32250.000
# 140     7603.000
# 165     9298.000
# 97      7999.000
# 203    22470.000
# 196    15985.000
# 21      5572.000
# 93      7349.000
# 192    13845.000
# 123     8921.000
# 120     6229.000
# 202    21485.000
# 2      16500.000
# 86      8189.000
# 115    16630.000
# 95      7799.000
# 89      5499.000
# 49     36000.000
# Name: price, dtype: float64

# %%
y_predict
# Out:
# array([15685.50548075, 22575.6835714 , 17201.97146968, 16139.36360473,
#        30774.86977591,  7778.5761506 ,  5625.05048798,  6541.95270638,
#        10347.06471691, 17008.51313417,  6675.72024504, 10346.80221106,
#         5358.46592432,  5484.23594181, 31442.62709835,  5827.91716094,
#        18672.57537954, 12445.08719601, 13625.24356844, 16486.33646918,
#         9575.26355678,  6611.99726388,  6508.79515632, 33613.16782252,
#         7966.39496518,  9424.20411509,  6452.77033034, 17349.86999935,
#        16139.36360473,  5827.91716094,  6452.77033034,  8659.37612411,
#        10744.45409549,  5827.91716094, 21945.74806249, 18659.26361945,
#        11384.75973153, 13890.27475707,  6505.36506493,  6508.79515632,
#        46763.7185067 ])

# %%
predictions = model.predict(X_test)

# %%
plt.scatter(y_test,predictions)

# %%
sns.regplot(x = "horsepower", y = "price", data = car1)
plt.show()

# %%
sns.regplot(x = "enginesize", y = "price", data = car1)
plt.show()

# %%
sns.regplot(x = "carwidth", y = "price", data = car1)
plt.show()

# %% [markdown]
# # Price Conclusion

# %% [markdown]
# ## 1.There is a significant difference between the mean and the median of the price distribution.
#
# ## 2.The data points are far spread out from the mean, which indicates a high variance in the car prices.(85% of the prices are below 18,500, whereas the remaining 15% are between 18,500 and 45,400.

# %% [markdown]
# ## 3.As per the analysis the price of car is more when the horsepower is above 100 and also its citympg decrease.
#
# ## 4. thus, if the automobile compnay want to introduce a new car they should keep the horsepower between 95-110 and also keep the fuel type gas for the better sale.
#
# ## 5.overall the price of a car depends upon the enginesize,horespower,and the dimension of car(height,weight,length,width)
#
# ## 6. thus this parameters should be balance by the compnay in order to increase their sales and profit.
